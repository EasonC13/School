# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

print(color.RED +"PriceTable 從零開始算，為了演算法方便\n"+color.END)
PriceTable = [0, 1, 5, 8, 9, 10, 17, 17, 20, 24, 30]


def CutRod(PriceTable, n, r = None, s = None):
    print("now running %d"%n, end = "")
    if n == 0 or n == 1:
        print("  return %d"%n)
        return n, r, s
    
    if r == None:
        r = createR(n)
    if s == None:
        s = createS(n)
        
    if r[n] != 0:
        print(" return %d for pervious example."%r[n])
        return r[n], r, s
    
    print(" Not found, start calculate:")
    currentMax = float('-inf')
    for i in range(0,n):
        print("split to %d, %d"%(i, n-i))
        cut = CutRod(PriceTable, i, r, s)[0] + PriceTable[n-i]
        print("This type of split (%d, %d) is = %d\n"%(i, n-i, cut))
        if currentMax < cut:
            currentMax = cut
            s[n] = i
    print(color.BOLD + "The max splite of %d is %d\n"%(n, currentMax) + color.END)
    r[n] = currentMax
    return currentMax, r, s
        
        
        
def createR(n):
    return [0] * (n+1)
def createS(n):
    return [0] * (n+1)

CutRod(PriceTable, 10)
# Out:
# PriceTable 從零開始算，為了演算法方便
#
# now running 10 Not found, start calculate:
# split to 0, 10
# now running 0  return 0
# This type of split (0, 10) is = 30
#
# split to 1, 9
# now running 1  return 1
# This type of split (1, 9) is = 25
#
# split to 2, 8
# now running 2 Not found, start calculate:
# split to 0, 2
# now running 0  return 0
# This type of split (0, 2) is = 5
#
# split to 1, 1
# now running 1  return 1
# This type of split (1, 1) is = 2
#
# The max splite of 2 is 5
#
# This type of split (2, 8) is = 25
#
# split to 3, 7
# now running 3 Not found, start calculate:
# split to 0, 3
# now running 0  return 0
# This type of split (0, 3) is = 8
#
# split to 1, 2
# now running 1  return 1
# This type of split (1, 2) is = 6
#
# split to 2, 1
# now running 2 return 5 for pervious example.
# This type of split (2, 1) is = 6
#
# The max splite of 3 is 8
#
# This type of split (3, 7) is = 25
#
# split to 4, 6
# now running 4 Not found, start calculate:
# split to 0, 4
# now running 0  return 0
# This type of split (0, 4) is = 9
#
# split to 1, 3
# now running 1  return 1
# This type of split (1, 3) is = 9
#
# split to 2, 2
# now running 2 return 5 for pervious example.
# This type of split (2, 2) is = 10
#
# split to 3, 1
# now running 3 return 8 for pervious example.
# This type of split (3, 1) is = 9
#
# The max splite of 4 is 10
#
# This type of split (4, 6) is = 27
#
# split to 5, 5
# now running 5 Not found, start calculate:
# split to 0, 5
# now running 0  return 0
# This type of split (0, 5) is = 10
#
# split to 1, 4
# now running 1  return 1
# This type of split (1, 4) is = 10
#
# split to 2, 3
# now running 2 return 5 for pervious example.
# This type of split (2, 3) is = 13
#
# split to 3, 2
# now running 3 return 8 for pervious example.
# This type of split (3, 2) is = 13
#
# split to 4, 1
# now running 4 return 10 for pervious example.
# This type of split (4, 1) is = 11
#
# The max splite of 5 is 13
#
# This type of split (5, 5) is = 23
#
# split to 6, 4
# now running 6 Not found, start calculate:
# split to 0, 6
# now running 0  return 0
# This type of split (0, 6) is = 17
#
# split to 1, 5
# now running 1  return 1
# This type of split (1, 5) is = 11
#
# split to 2, 4
# now running 2 return 5 for pervious example.
# This type of split (2, 4) is = 14
#
# split to 3, 3
# now running 3 return 8 for pervious example.
# This type of split (3, 3) is = 16
#
# split to 4, 2
# now running 4 return 10 for pervious example.
# This type of split (4, 2) is = 15
#
# split to 5, 1
# now running 5 return 13 for pervious example.
# This type of split (5, 1) is = 14
#
# The max splite of 6 is 17
#
# This type of split (6, 4) is = 26
#
# split to 7, 3
# now running 7 Not found, start calculate:
# split to 0, 7
# now running 0  return 0
# This type of split (0, 7) is = 17
#
# split to 1, 6
# now running 1  return 1
# This type of split (1, 6) is = 18
#
# split to 2, 5
# now running 2 return 5 for pervious example.
# This type of split (2, 5) is = 15
#
# split to 3, 4
# now running 3 return 8 for pervious example.
# This type of split (3, 4) is = 17
#
# split to 4, 3
# now running 4 return 10 for pervious example.
# This type of split (4, 3) is = 18
#
# split to 5, 2
# now running 5 return 13 for pervious example.
# This type of split (5, 2) is = 18
#
# split to 6, 1
# now running 6 return 17 for pervious example.
# This type of split (6, 1) is = 18
#
# The max splite of 7 is 18
#
# This type of split (7, 3) is = 26
#
# split to 8, 2
# now running 8 Not found, start calculate:
# split to 0, 8
# now running 0  return 0
# This type of split (0, 8) is = 20
#
# split to 1, 7
# now running 1  return 1
# This type of split (1, 7) is = 18
#
# split to 2, 6
# now running 2 return 5 for pervious example.
# This type of split (2, 6) is = 22
#
# split to 3, 5
# now running 3 return 8 for pervious example.
# This type of split (3, 5) is = 18
#
# split to 4, 4
# now running 4 return 10 for pervious example.
# This type of split (4, 4) is = 19
#
# split to 5, 3
# now running 5 return 13 for pervious example.
# This type of split (5, 3) is = 21
#
# split to 6, 2
# now running 6 return 17 for pervious example.
# This type of split (6, 2) is = 22
#
# split to 7, 1
# now running 7 return 18 for pervious example.
# This type of split (7, 1) is = 19
#
# The max splite of 8 is 22
#
# This type of split (8, 2) is = 27
#
# split to 9, 1
# now running 9 Not found, start calculate:
# split to 0, 9
# now running 0  return 0
# This type of split (0, 9) is = 24
#
# split to 1, 8
# now running 1  return 1
# This type of split (1, 8) is = 21
#
# split to 2, 7
# now running 2 return 5 for pervious example.
# This type of split (2, 7) is = 22
#
# split to 3, 6
# now running 3 return 8 for pervious example.
# This type of split (3, 6) is = 25
#
# split to 4, 5
# now running 4 return 10 for pervious example.
# This type of split (4, 5) is = 20
#
# split to 5, 4
# now running 5 return 13 for pervious example.
# This type of split (5, 4) is = 22
#
# split to 6, 3
# now running 6 return 17 for pervious example.
# This type of split (6, 3) is = 25
#
# split to 7, 2
# now running 7 return 18 for pervious example.
# This type of split (7, 2) is = 23
#
# split to 8, 1
# now running 8 return 22 for pervious example.
# This type of split (8, 1) is = 23
#
# The max splite of 9 is 25
#
# This type of split (9, 1) is = 26
#
# The max splite of 10 is 30
# (30,
#  [0, 0, 5, 8, 10, 13, 17, 18, 22, 25, 30],
#  [0, 0, 0, 0, 2, 2, 0, 1, 2, 3, 0])
